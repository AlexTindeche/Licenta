# %% [markdown]
# # Counts people depending on the colour of the traffic ligth

# %% [markdown]
# # Imports and setup

# %%
###################### Imports #######################


###############
# Ultralytics #
###############

# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()

######################
# Set Home Directory #
######################

import os
HOME = os.getcwd()
print(HOME)

######################
# Import yolox modek #
######################

# %cd {HOME}
# !git clone https://github.com/ifzhang/ByteTrack.git
# %cd {HOME}/ByteTrack

# # workaround related to https://github.com/roboflow/notebooks/issues/80
# !sed -i 's/onnx==1.8.1/onnx==1.9.0/g' requirements.txt

# !pip3 install -q -r requirements.txt
# !python3 setup.py -q develop
# !pip install -q cython_bbox
# !pip install -q onemetric
# # workaround related to https://github.com/roboflow/notebooks/issues/112 and https://github.com/roboflow/notebooks/issues/106
# !pip install -q loguru lap thop

from IPython import display
display.clear_output()


import sys
sys.path.append(f"{HOME}/ByteTrack")


import yolox
print("yolox.__version__:", yolox.__version__)

##########################
# Import ByteTrack model #
##########################

from yolox.tracker.byte_tracker import BYTETracker, STrack
from onemetric.cv.utils.iou import box_iou_batch
from dataclasses import dataclass


@dataclass(frozen=True)
class BYTETrackerArgs:
    track_thresh: float = 0.25
    track_buffer: int = 30
    match_thresh: float = 0.8
    aspect_ratio_thresh: float = 3.0
    min_box_area: float = 1.0
    mot20: bool = False


######################
# Import Supervision #
######################
    
# !pip install supervision==0.1.0


from IPython import display
display.clear_output()


import supervision
print("supervision.__version__:", supervision.__version__)

from supervision.draw.color import ColorPalette
from supervision.draw.color import Color
from supervision.geometry.dataclasses import Point
from supervision.video.dataclasses import VideoInfo
from supervision.video.source import get_video_frames_generator
from supervision.video.sink import VideoSink
from supervision.notebook.utils import show_frame_in_notebook
from supervision.tools.detections import Detections, BoxAnnotator
from supervision.tools.line_counter import LineCounter, LineCounterAnnotator

####################### Setups #######################

######################
# ByteTrack settings #
######################

from typing import List

import numpy as np


# converts Detections into format that can be consumed by match_detections_with_tracks function
def detections2boxes(detections: Detections) -> np.ndarray:
    return np.hstack((
        detections.xyxy,
        detections.confidence[:, np.newaxis]
    ))


# converts List[STrack] into format that can be consumed by match_detections_with_tracks function
def tracks2boxes(tracks: List[STrack]) -> np.ndarray:
    return np.array([
        track.tlbr
        for track
        in tracks
    ], dtype=float)


# matches our bounding boxes with predictions
def match_detections_with_tracks(
    detections: Detections,
    tracks: List[STrack]
) -> Detections:
    if not np.any(detections.xyxy) or len(tracks) == 0:
        return np.empty((0,))

    tracks_boxes = tracks2boxes(tracks=tracks)
    iou = box_iou_batch(tracks_boxes, detections.xyxy)
    track2detection = np.argmax(iou, axis=1)

    tracker_ids = [None] * len(detections)

    for tracker_index, detection_index in enumerate(track2detection):
        if iou[tracker_index, detection_index] != 0:
            tracker_ids[detection_index] = tracks[tracker_index].track_id

    return tracker_ids


##################
# YoloX settings #
##################
from ultralytics import YOLO

MODEL = "yolov8x.pt"


model = YOLO(MODEL)
model.fuse()
# Out:
# supervision.__version__: 0.1.0
# YOLOv8x summary (fused): 268 layers, 68200608 parameters, 0 gradients, 257.8 GFLOPs

# %% [markdown]
# # Paths and other constants

# %%
###################### Paths #######################

SOURCE_VIDEO_PATH = "../Videos/00001-converted.mp4"

TARGET_VIDEO_PATH = f"{HOME}/vehicle-counting-result.mp4"

print(f"SOURCE_VIDEO_PATH: {SOURCE_VIDEO_PATH}")
print(f"TARGET_VIDEO_PATH: {TARGET_VIDEO_PATH}")

VideoInfo.from_video_path(SOURCE_VIDEO_PATH)

###################### Class constants #######################

# dict maping class_id to class_name
CLASS_NAMES_DICT = model.model.names
# class_ids of interest - person, car, motorcycle, bus and truck
CLASS_ID = [0, 2, 3, 5, 7]
CLASS_ID_PEOPLE = [0]
CLASS_ID_VEHICLE = [2, 3, 5, 7]
CLASS_ID_TRAFFIC_LIGHT = [9]
# Out:
# SOURCE_VIDEO_PATH: ../Videos/00001-converted.mp4
# TARGET_VIDEO_PATH: /mnt/Storage/Licenta-main/Licenta/vehicle-counting-result.mp4

# %% [markdown]
# # Counting algorithm

# %% [markdown]
# ### Setup of traffic light classifier

# %%
# !pip install traffic_light_classifier

import traffic_light_classifier as tlc


model_traffic_light = tlc.Model()
model_traffic_light.compile()

###################### Functions #######################

#####################################################
# HSV color space ranges for red, yellow, and green #
#####################################################

import cv2
import numpy as np

def predict_traffic_light_color(frame):
    # Convert to HSV color space
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    # Define hue ranges for red, yellow, and green (these ranges might need adjustment)
    red_lower1 = np.array([0, 100, 100])
    red_upper1 = np.array([160, 100, 100])
    red_lower2 = np.array([160, 50, 50])
    red_upper2 = np.array([180, 255, 255])
    yellow_lower = np.array([20, 50, 50])
    yellow_upper = np.array([30, 255, 255])
    green_lower = np.array([40, 50, 50])
    green_upper = np.array([90, 255, 255])
    # Count pixels within each color range
    red_pixels = (cv2.inRange(hsv, red_lower1, red_upper1) > 0).sum() + (cv2.inRange(hsv, red_lower2, red_upper2) > 0).sum()
    yellow_pixels = (cv2.inRange(hsv, yellow_lower, yellow_upper) > 0).sum()
    green_pixels = (cv2.inRange(hsv, green_lower, green_upper) > 0).sum()
    # Determine the most prominent color
    print(f"red_pixels: {red_pixels}, yellow_pixels: {yellow_pixels}, green_pixels: {green_pixels}")
    if red_pixels <= 30 and yellow_pixels <= 30 and green_pixels <= 30:
        return "Unknown"
    if max(red_pixels, yellow_pixels, green_pixels) == red_pixels:
        return "Red"
    elif max(red_pixels, yellow_pixels, green_pixels) == yellow_pixels:
        return "Yellow"
    else:
        return "Green"
# Out:
# ==========================================================================
# Importing package 'traffic_light_classifier'...
# ==========================================================================
#   + Adding module 'helpers'...
#   - Done!
#   + Adding module 'tests'...
#   - Done!
#   + Adding module 'plots'...
#   - Done!
#   + Adding module 'modify_images'...
#   - Done!
#   + Adding module 'extract_feature'...
#   - Done!
#   + Adding module 'statistics'...
#   - Done!
#   + Adding module 'datasets'...
#   - Done!
#   + Adding module 'model'...
#   - Done!
# ==========================================================================
# Package 'traffic_light_classifier' imported sucessfully !!
# ==========================================================================
# version 1.0.0
#
#
# Compilation in progress... Please wait !!
# #### <span style='color: green;'>Compilation complete !!</span>

# %% [markdown]
# #### Select counting lines coodrinates

# %%
###################### Select line #######################

import cv2
import numpy as np

# Initialize global variables
points = []  # To store the points where you click
lines = []

# Callback function for mouse events
def click_event(event, x, y, flags, param):
    global points, img, scaleFactorX, scaleFactorY
    if event == cv2.EVENT_LBUTTONDOWN:  # Left button click
        if len(points) < 2:  # Ensure we only have 2 points
            # Adjust x, y back to original image scale
            origX = int(x * scaleFactorX)
            origY = int(y * scaleFactorY)
            points.append((origX, origY))
            cv2.circle(resized_img, (x, y), 5, (0, 0, 255), -1)  # Draw the dot on resized image
            if len(points) == 2:
                lines.append((points[0], points[1]))
                cv2.line(resized_img, 
                    (int(points[0][0] // scaleFactorX), int(points[0][1] // scaleFactorY)),
                    (int(points[1][0] // scaleFactorX), int(points[1][1] // scaleFactorY)), 
                    (255, 0, 0), 2)  # Draw the line on resized image
                print(f"Point 1: {points[0]}, Point 2: {points[1]}")  # Print coordinates of original points
                cv2.imshow("image", resized_img)  # Show the image with the line
                
    if len(points) == 2:  # Reset after 2 points for new line drawing
        points.clear()



# Create a black image
generator = get_video_frames_generator(SOURCE_VIDEO_PATH)
# create instance of BoxAnnotator
box_annotator = BoxAnnotator(color=ColorPalette(), thickness=4, text_thickness=4, text_scale=2)
# acquire first video frame
iterator = iter(generator)
frame = next(iterator)
# Resize the image to 200x200
resized_img = cv2.resize(frame, (1000, 800))

# Calculate scale factors
originalHeight, originalWidth = frame.shape[:2]
scaleFactorX = originalWidth / 1000
scaleFactorY = originalHeight / 800

cv2.namedWindow("image")
cv2.setMouseCallback("image", click_event)

cv2.imshow("image", resized_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

line_start = Point(lines[0][0][0], lines[0][0][1])
line_end = Point(lines[0][1][0], lines[0][1][1])

line_cars_start = Point(lines[1][0][0], lines[1][0][1])
line_cars_end = Point(lines[1][1][0], lines[1][1][1])

print(f"line_start: {line_start}, line_end: {line_end}")
print(f"line_cars_start: {line_cars_start}, line_cars_end: {line_cars_end}")
# Out:
# Point 1: (164, 608), Point 2: (1160, 603)
# Point 1: (577, 1), Point 2: (743, 1075)
# line_start: Point(x=164, y=608), line_end: Point(x=1160, y=603)
# line_cars_start: Point(x=577, y=1), line_cars_end: Point(x=743, y=1075)

# %% [markdown]
# ### Override the update function for line_counter

# %%
# Override the update function from line_counter.py

from supervision.tools.line_counter import LineCounter

class LineCounter(LineCounter):
    def update(self, detections: Detections):
        """
        Update the in_count and out_count for the detections that cross the line.

        :param detections: Detections : The detections for which to update the counts.
        """
        for xyxy, confidence, class_id, tracker_id in detections:
            # If there is no tracker_id, we skip the detection
            if tracker_id is None:
                continue

            # See how many points are on each side of the line
            x1, y1, x2, y2 = xyxy
            # anchors = [
            #     Point(x=x1, y=y1),
            #     Point(x=x1, y=y2),
            #     Point(x=x2, y=y1),
            #     Point(x=x2, y=y2),
            # ]

            # Workaround for the fact that the bboxes are too big

            '''
                Introduce a padding so the bbox will be the one in the interior of the original one, like so:
                |-----------------------|
                |  \                  / |
                |   \---------------/   |
                |   |Bbox w padding |   |
                |   /---------------\   |
                | /                  \  |
                |-----------------------|
            
            '''
            # Preduce the box by 40% of its original size
            percentange = 0.3
            anchors = [
                Point(x=x1 + (x2 - x1) * percentange, y=y1 + (y2 - y1) * percentange),
                Point(x=x1 + (x2 - x1) * percentange, y=y2 - (y2 - y1) * percentange),
                Point(x=x2 - (x2 - x1) * percentange, y=y1 + (y2 - y1) * percentange),
                Point(x=x2 - (x2 - x1) * percentange, y=y2 - (y2 - y1) * percentange),
            ]


            # Bool list. The truth value indicates the side of the line the point is on.
            triggers = [self.vector.is_in(point=anchor) for anchor in anchors]

            # detection is partially in and partially out
            if len(set(triggers)) == 2:
                continue

            tracker_state = triggers[0]
            # handle new detection
            if tracker_id not in self.tracker_state:
                self.tracker_state[tracker_id] = tracker_state
                continue

            # handle detection on the same side of the line
            if self.tracker_state.get(tracker_id) == tracker_state:
                continue

            self.tracker_state[tracker_id] = tracker_state
            if tracker_state:
                self.in_count += 1
            else:
                self.out_count += 1

# %% [markdown]
# ### Predict on whole video

# %%
from tqdm.notebook import tqdm
import cv2
from numpy import argmax


def annotate_with_counts(frame, frame_nr, people_count_green, vehicles_count_green, people_count_red, vehicles_count_red, font_scale=1, thickness=2):
    # Set the position for the annotations on the frame
    position_people_green = (10, 30)
    position_vehicles_green = (10, 60)
    position_people_red = (1000, 30)
    position_vehicles_red = (1000, 60)
    frame_number_position = (10, 1000)
    font = cv2.FONT_HERSHEY_SIMPLEX
    cv2.putText(frame, f"People crossed on green: {people_count_green}", position_people_green, font, font_scale, (255, 255, 0), thickness)
    cv2.putText(frame, f"Vehicles crossed on green: {vehicles_count_green}", position_vehicles_green, font, font_scale, (0, 255, 0), thickness)
    cv2.putText(frame, f"People crossed on red: {people_count_red}", position_people_red, font, font_scale, (0, 255, 255), thickness)
    cv2.putText(frame, f"Vehicles crossed on red: {vehicles_count_red}", position_vehicles_red, font, font_scale, (255, 0, 255), thickness)
    cv2.putText(frame, f"Frame: {frame_nr}", frame_number_position, font, font_scale, (255, 255, 255), thickness)


# create BYTETracker instance
byte_tracker = BYTETracker(BYTETrackerArgs())
# create VideoInfo instance
video_info = VideoInfo.from_video_path(SOURCE_VIDEO_PATH)
# create frame generator
generator = get_video_frames_generator(SOURCE_VIDEO_PATH)
# create LineCounter instance
line_counter_people = LineCounter(start=line_start, end=line_end)
line_counter_vehicles = LineCounter(start=line_cars_start, end=line_cars_end)
line_counter_people_green = LineCounter(start=line_start, end=line_end)
line_counter_people_red = LineCounter(start=line_start, end=line_end)
line_counter_vehicles_green = LineCounter(start=line_cars_start, end=line_cars_end)
line_counter_vehicles_red = LineCounter(start=line_cars_start, end=line_cars_end)
# create instance of BoxAnnotator and LineCounterAnnotator
box_annotator = BoxAnnotator(color=ColorPalette(), thickness=3, text_thickness=4, text_scale=2)
line_annotator_people = LineCounterAnnotator(thickness=3, text_thickness=4, text_scale=1)
line_annotator_vehicle = LineCounterAnnotator(thickness=3, text_thickness=4, text_scale=1, color=Color(0, 255, 0))

# open target video file
with VideoSink(TARGET_VIDEO_PATH, video_info) as sink:
    # loop over video frames
    for frame_nr, frame in enumerate(tqdm(generator, total=video_info.total_frames), start=1):        # model prediction on single frame and conversion to supervision Detections
        print(f"frame_nr: {frame_nr}")
        results = model(frame)
        detections = Detections(
            xyxy=results[0].boxes.xyxy.cpu().numpy(),
            confidence=results[0].boxes.conf.cpu().numpy(),
            class_id=results[0].boxes.cls.cpu().numpy().astype(int)
        )
        detections_people = Detections(
            xyxy=results[0].boxes.xyxy.cpu().numpy(),
            confidence=results[0].boxes.conf.cpu().numpy(),
            class_id=results[0].boxes.cls.cpu().numpy().astype(int)
        )
        detections_vehicles = Detections(
            xyxy=results[0].boxes.xyxy.cpu().numpy(),
            confidence=results[0].boxes.conf.cpu().numpy(),
            class_id=results[0].boxes.cls.cpu().numpy().astype(int)
        )
        detections_traffic_light = Detections(
            xyxy=results[0].boxes.xyxy.cpu().numpy(),
            confidence=results[0].boxes.conf.cpu().numpy(),
            class_id=results[0].boxes.cls.cpu().numpy().astype(int)
        )
        # filtering out detections with unwanted classes
        mask_people = np.array([class_id in CLASS_ID_PEOPLE for class_id in detections.class_id], dtype=bool)
        mask_vehicle = np.array([class_id in CLASS_ID_VEHICLE for class_id in detections.class_id], dtype=bool)
        mask_traffic_light= np.array([class_id in CLASS_ID_TRAFFIC_LIGHT for class_id in detections.class_id], dtype=bool)
        detections_people.filter(mask=mask_people, inplace=True)
        detections_vehicles.filter(mask=mask_vehicle, inplace=True)
        detections_traffic_light.filter(mask=mask_traffic_light, inplace=True)
        mask = np.array([class_id in CLASS_ID for class_id in detections.class_id], dtype=bool)
        detections.filter(mask=mask, inplace=True)
        # tracking detections
        tracks_people = byte_tracker.update(
            output_results=detections2boxes(detections=detections_people),
            img_info=frame.shape,
            img_size=frame.shape
        )
        tracks_vehicles = byte_tracker.update(
            output_results=detections2boxes(detections=detections_vehicles),
            img_info=frame.shape,
            img_size=frame.shape
        )
        tracks = byte_tracker.update(
            output_results=detections2boxes(detections=detections),
            img_info=frame.shape,
            img_size=frame.shape
        )
        tracker_id = match_detections_with_tracks(detections=detections, tracks=tracks)
        tracker_id_people = match_detections_with_tracks(detections=detections_people, tracks=tracks_people)
        tracker_id_vehicles = match_detections_with_tracks(detections=detections_vehicles, tracks=tracks_vehicles)
        detections.tracker_id = np.array(tracker_id)
        detections_people.tracker_id = np.array(tracker_id_people)
        detections_vehicles.tracker_id = np.array(tracker_id_vehicles)
        # filtering out detections without trackers
        mask = np.array([tracker_id is not None for tracker_id in detections.tracker_id], dtype=bool)
        mask_people = np.array([tracker_id is not None for tracker_id in detections_people.tracker_id], dtype=bool)
        mask_vehicles = np.array([tracker_id is not None for tracker_id in detections_vehicles.tracker_id], dtype=bool)
        detections.filter(mask=mask, inplace=True)
        detections_people.filter(mask=mask_people, inplace=True)
        detections_vehicles.filter(mask=mask_vehicles, inplace=True)

        # Cut the box around the traffic light
        ok = False
        traffic_light_color = "Unknown"
        for detection in detections_traffic_light.xyxy:
            # %matplotlib inline
            x1, y1, x2, y2 = detection.astype(int)
            frame1 = frame[y1:y2, x1:x2]


            # Predict the color of the traffic light
            colours = ["Red", "Yellow", "Green"]
            color = predict_traffic_light_color(frame1)
            # print(f"Traffic light color: {color}")
            if color != "Unknown":
                frame1 = cv2.cvtColor(frame1, cv2.COLOR_BGR2RGB)
                frame1 = cv2.resize(frame1, (32, 32))
                if frame1.size == 0:
                    raise ValueError("The cropped image is empty.")
                pred = model_traffic_light.predict(frame1, show_analysis=False)
                print(f"pred: {pred}")
                if colours[argmax(pred)] != color:
                    print(f"!!! hsv: {color}, nn: {colours[argmax(pred)]}")
                print(f"Traffic light color: {colours[argmax(pred)]}")
                traffic_light_color = colours[argmax(pred)]
            else:
                print("Traffic light color: not visible")
            text_position = (x1, y1 - 10 if y1 - 10 > 0 else y1 + 20)
            font_scale = 0.7  
            thickness = 2  
            cv2.putText(frame, traffic_light_color[0], text_position, cv2.FONT_HERSHEY_SIMPLEX, font_scale, (0, 255, 0), thickness)
        
        print(f"Traffic light color after for: {traffic_light_color}")

        # updating line counter if the traffic light is green
        if traffic_light_color == "Green":
            line_counter_people_green.update(detections=detections_people)
            line_counter_vehicles_red.update(detections=detections_vehicles)
        elif traffic_light_color == "Red":
            line_counter_people_red.update(detections=detections_people)
            line_counter_vehicles_green.update(detections=detections_vehicles)

        line_counter_people.update(detections=detections_people)
        line_counter_vehicles.update(detections=detections_vehicles)


        # annotate and display frame
        line_annotator_people.annotate(frame=frame, line_counter=line_counter_people)
        line_annotator_vehicle.annotate(frame=frame, line_counter=line_counter_vehicles)
        annotate_with_counts(frame, frame_nr, line_counter_people_green.in_count + line_counter_people_green.out_count, 
                             line_counter_vehicles_green.in_count + line_counter_vehicles_green.out_count, 
                             line_counter_people_red.in_count + line_counter_people_red.out_count, 
                             line_counter_vehicles_red.in_count + line_counter_vehicles_red.out_count)
        print(f"people crossed on green: {line_counter_people_green.in_count + line_counter_people_green.out_count}")
        print(f"vehicles crossed on green: {line_counter_vehicles_green.in_count + line_counter_vehicles_green.out_count}")
        print(f"people crossed on red: {line_counter_people_red.in_count + line_counter_people_red.out_count}")
        print(f"vehicles crossed on red: {line_counter_vehicles_red.in_count + line_counter_vehicles_red.out_count}")
        print(f"people crossed: {line_counter_people.in_count + line_counter_people.out_count}")
        print(f"vehicles crossed: {line_counter_vehicles.in_count + line_counter_vehicles.out_count}")
        sink.write_frame(frame)
# Out:
#   0%|          | 0/2559 [00:00<?, ?it/s]
# frame_nr: 1
#
# 0: 480x640 15 persons, 6 cars, 2 traffic lights, 1 stop sign, 55.6ms
# Speed: 1.7ms preprocess, 55.6ms inference, 167.4ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 175, yellow_pixels: 0, green_pixels: 4
# pred: [1, 0, 0]
# Traffic light color: Red
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 2
#
# 0: 480x640 16 persons, 6 cars, 2 traffic lights, 1 stop sign, 1 suitcase, 33.6ms
# Speed: 1.2ms preprocess, 33.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 176, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 3
#
# 0: 480x640 15 persons, 6 cars, 1 traffic light, 1 stop sign, 1 suitcase, 33.8ms
# Speed: 1.2ms preprocess, 33.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 161, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 4
#
# 0: 480x640 16 persons, 6 cars, 2 traffic lights, 1 stop sign, 1 suitcase, 33.1ms
# Speed: 1.3ms preprocess, 33.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 181, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 5
#
# 0: 480x640 15 persons, 7 cars, 1 traffic light, 1 stop sign, 1 suitcase, 32.0ms
# Speed: 1.3ms preprocess, 32.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 161, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 6
#
# 0: 480x640 13 persons, 8 cars, 2 traffic lights, 1 stop sign, 1 suitcase, 31.1ms
# Speed: 1.3ms preprocess, 31.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 169, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 7
#
# 0: 480x640 13 persons, 7 cars, 3 traffic lights, 1 stop sign, 31.0ms
# Speed: 1.3ms preprocess, 31.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 168, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 8
#
# 0: 480x640 15 persons, 8 cars, 1 traffic light, 1 stop sign, 32.1ms
# Speed: 1.2ms preprocess, 32.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 160, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 9
#
# 0: 480x640 16 persons, 8 cars, 1 traffic light, 1 stop sign, 32.1ms
# Speed: 1.3ms preprocess, 32.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 157, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 10
#
# 0: 480x640 16 persons, 8 cars, 2 traffic lights, 1 stop sign, 32.0ms
# Speed: 1.4ms preprocess, 32.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 165, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 11
#
# 0: 480x640 15 persons, 7 cars, 2 traffic lights, 1 stop sign, 31.9ms
# Speed: 1.2ms preprocess, 31.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 165, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 12
#
# 0: 480x640 16 persons, 7 cars, 2 traffic lights, 1 stop sign, 31.9ms
# Speed: 1.2ms preprocess, 31.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 158, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 13
#
# 0: 480x640 16 persons, 8 cars, 1 traffic light, 1 stop sign, 30.6ms
# Speed: 1.2ms preprocess, 30.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 156, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 14
#
# 0: 480x640 16 persons, 8 cars, 2 traffic lights, 1 stop sign, 30.6ms
# Speed: 1.2ms preprocess, 30.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 170, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 15
#
# 0: 480x640 16 persons, 7 cars, 2 traffic lights, 1 stop sign, 31.4ms
# Speed: 1.2ms preprocess, 31.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 160, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 16
#
# 0: 480x640 16 persons, 7 cars, 2 traffic lights, 1 stop sign, 31.9ms
# Speed: 1.2ms preprocess, 31.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 160, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 17
#
# 0: 480x640 15 persons, 7 cars, 2 traffic lights, 1 stop sign, 31.8ms
# Speed: 1.3ms preprocess, 31.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 168, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 18
#
# 0: 480x640 16 persons, 7 cars, 2 traffic lights, 1 stop sign, 32.1ms
# Speed: 2.5ms preprocess, 32.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 151, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 19
#
# 0: 480x640 16 persons, 7 cars, 2 traffic lights, 1 stop sign, 32.0ms
# Speed: 1.3ms preprocess, 32.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 161, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 20
#
# 0: 480x640 15 persons, 6 cars, 2 traffic lights, 1 stop sign, 32.0ms
# Speed: 1.3ms preprocess, 32.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 177, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 21
#
# 0: 480x640 15 persons, 6 cars, 2 traffic lights, 1 stop sign, 32.0ms
# Speed: 1.9ms preprocess, 32.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 172, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 22
#
# 0: 480x640 15 persons, 5 cars, 2 traffic lights, 1 stop sign, 31.9ms
# Speed: 1.2ms preprocess, 31.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 184, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 23
#
# 0: 480x640 16 persons, 6 cars, 2 traffic lights, 1 stop sign, 30.6ms
# Speed: 1.2ms preprocess, 30.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 164, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 24
#
# 0: 480x640 14 persons, 6 cars, 2 traffic lights, 1 stop sign, 1 handbag, 30.7ms
# Speed: 1.4ms preprocess, 30.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 173, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 25
#
# 0: 480x640 16 persons, 6 cars, 3 traffic lights, 1 stop sign, 31.9ms
# Speed: 1.1ms preprocess, 31.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 180, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 0, yellow_pixels: 0, green_pixels: 1
# Traffic light color: not visible
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 26
#
# 0: 480x640 16 persons, 7 cars, 3 traffic lights, 1 stop sign, 1 handbag, 31.8ms
# Speed: 1.1ms preprocess, 31.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 165, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# red_pixels: 165, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 27
#
# 0: 480x640 15 persons, 6 cars, 2 traffic lights, 1 stop sign, 1 suitcase, 31.8ms
# Speed: 1.2ms preprocess, 31.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 172, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 28
#
# 0: 480x640 17 persons, 7 cars, 2 traffic lights, 1 stop sign, 31.9ms
# Speed: 1.2ms preprocess, 31.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 187, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 29
#
# 0: 480x640 15 persons, 7 cars, 2 traffic lights, 1 stop sign, 1 handbag, 32.0ms
# Speed: 1.3ms preprocess, 32.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 174, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 30
#
# 0: 480x640 15 persons, 6 cars, 2 traffic lights, 1 stop sign, 1 handbag, 32.2ms
# Speed: 1.8ms preprocess, 32.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 163, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 31
#
# 0: 480x640 15 persons, 6 cars, 2 traffic lights, 1 stop sign, 31.8ms
# Speed: 1.2ms preprocess, 31.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 180, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 32
#
# 0: 480x640 15 persons, 6 cars, 2 traffic lights, 1 stop sign, 31.1ms
# Speed: 1.2ms preprocess, 31.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 188, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 33
#
# 0: 480x640 15 persons, 7 cars, 2 traffic lights, 1 stop sign, 31.3ms
# Speed: 2.2ms preprocess, 31.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 162, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 34
#
# 0: 480x640 14 persons, 7 cars, 2 traffic lights, 1 suitcase, 30.6ms
# Speed: 1.2ms preprocess, 30.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 166, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 35
#
# 0: 480x640 15 persons, 8 cars, 2 traffic lights, 1 stop sign, 30.8ms
# Speed: 1.3ms preprocess, 30.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 182, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 36
#
# 0: 480x640 15 persons, 7 cars, 2 traffic lights, 1 stop sign, 1 handbag, 31.8ms
# Speed: 1.3ms preprocess, 31.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 184, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 37
#
# 0: 480x640 15 persons, 7 cars, 3 traffic lights, 1 stop sign, 1 handbag, 31.8ms
# Speed: 1.1ms preprocess, 31.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 183, yellow_pixels: 0, green_pixels: 2
# pred: [1, 0, 0]
# Traffic light color: Red
# red_pixels: 183, yellow_pixels: 0, green_pixels: 11
# pred: [0, 0, 1]
# !!! hsv: Red, nn: Green
# Traffic light color: Green
# Traffic light color after for: Green
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 38
#
# 0: 480x640 16 persons, 6 cars, 2 traffic lights, 1 stop sign, 31.9ms
# Speed: 1.2ms preprocess, 31.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 168, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 39
#
# 0: 480x640 16 persons, 6 cars, 1 truck, 2 traffic lights, 1 stop sign, 32.1ms
# Speed: 1.3ms preprocess, 32.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 173, yellow_pixels: 0, green_pixels: 6
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 40
#
# 0: 480x640 16 persons, 6 cars, 2 traffic lights, 1 stop sign, 31.9ms
# Speed: 1.5ms preprocess, 31.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 186, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 41
#
# 0: 480x640 17 persons, 8 cars, 2 traffic lights, 1 stop sign, 31.8ms
# Speed: 1.2ms preprocess, 31.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 169, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 42
#
# 0: 480x640 15 persons, 6 cars, 3 traffic lights, 1 stop sign, 31.9ms
# Speed: 1.3ms preprocess, 31.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 172, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# red_pixels: 172, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 43
#
# 0: 480x640 15 persons, 6 cars, 2 traffic lights, 1 stop sign, 31.8ms
# Speed: 1.3ms preprocess, 31.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 171, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 44
#
# 0: 480x640 15 persons, 6 cars, 2 traffic lights, 1 stop sign, 32.1ms
# Speed: 1.3ms preprocess, 32.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 172, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 45
#
# 0: 480x640 14 persons, 6 cars, 2 traffic lights, 1 stop sign, 30.7ms
# Speed: 1.3ms preprocess, 30.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 176, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 46
#
# 0: 480x640 15 persons, 6 cars, 2 traffic lights, 1 stop sign, 31.0ms
# Speed: 1.5ms preprocess, 31.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 180, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 47
#
# 0: 480x640 15 persons, 6 cars, 2 traffic lights, 1 stop sign, 32.0ms
# Speed: 1.2ms preprocess, 32.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 172, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 48
#
# 0: 480x640 14 persons, 5 cars, 3 traffic lights, 1 stop sign, 32.1ms
# Speed: 1.3ms preprocess, 32.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 171, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# red_pixels: 171, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 49
#
# 0: 480x640 15 persons, 5 cars, 2 traffic lights, 1 stop sign, 31.9ms
# Speed: 1.2ms preprocess, 31.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 164, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 50
#
# 0: 480x640 15 persons, 6 cars, 2 traffic lights, 1 stop sign, 31.9ms
# Speed: 1.2ms preprocess, 31.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 168, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 51
#
# 0: 480x640 15 persons, 6 cars, 2 traffic lights, 1 stop sign, 31.8ms
# Speed: 1.3ms preprocess, 31.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 168, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 52
#
# 0: 480x640 15 persons, 6 cars, 2 traffic lights, 1 stop sign, 31.1ms
# Speed: 1.4ms preprocess, 31.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 168, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 53
#
# 0: 480x640 14 persons, 6 cars, 2 traffic lights, 1 stop sign, 30.7ms
# Speed: 1.4ms preprocess, 30.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 174, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 54
#
# 0: 480x640 14 persons, 6 cars, 2 traffic lights, 1 stop sign, 32.1ms
# Speed: 1.1ms preprocess, 32.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 174, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 55
#
# 0: 480x640 14 persons, 6 cars, 1 truck, 2 traffic lights, 1 stop sign, 31.9ms
# Speed: 1.4ms preprocess, 31.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 164, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 56
#
# 0: 480x640 14 persons, 6 cars, 1 truck, 2 traffic lights, 1 stop sign, 32.2ms
# Speed: 1.4ms preprocess, 32.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 164, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 57
#
# 0: 480x640 15 persons, 7 cars, 1 truck, 2 traffic lights, 1 stop sign, 1 handbag, 32.0ms
# Speed: 1.7ms preprocess, 32.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 164, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 58
#
# 0: 480x640 16 persons, 5 cars, 2 traffic lights, 1 stop sign, 32.2ms
# Speed: 1.3ms preprocess, 32.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 172, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 59
#
# 0: 480x640 15 persons, 5 cars, 2 traffic lights, 1 stop sign, 32.0ms
# Speed: 1.2ms preprocess, 32.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 168, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 60
#
# 0: 480x640 15 persons, 5 cars, 2 traffic lights, 1 stop sign, 31.2ms
# Speed: 1.2ms preprocess, 31.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 168, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 61
#
# 0: 480x640 15 persons, 7 cars, 2 traffic lights, 1 stop sign, 30.8ms
# Speed: 1.8ms preprocess, 30.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 169, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 62
#
# 0: 480x640 15 persons, 7 cars, 2 traffic lights, 1 stop sign, 31.2ms
# Speed: 1.2ms preprocess, 31.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 173, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 63
#
# 0: 480x640 15 persons, 7 cars, 2 traffic lights, 1 stop sign, 1 backpack, 30.7ms
# Speed: 1.2ms preprocess, 30.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 180, yellow_pixels: 0, green_pixels: 2
# pred: [1, 0, 0]
# Traffic light color: Red
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 64
#
# 0: 480x640 15 persons, 6 cars, 2 traffic lights, 1 stop sign, 31.4ms
# Speed: 1.3ms preprocess, 31.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 190, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 65
#
# 0: 480x640 15 persons, 6 cars, 2 traffic lights, 1 stop sign, 1 backpack, 32.1ms
# Speed: 1.2ms preprocess, 32.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 176, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 66
#
# 0: 480x640 14 persons, 6 cars, 1 truck, 3 traffic lights, 1 stop sign, 32.0ms
# Speed: 1.2ms preprocess, 32.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 177, yellow_pixels: 0, green_pixels: 2
# pred: [1, 0, 0]
# Traffic light color: Red
# red_pixels: 178, yellow_pixels: 0, green_pixels: 9
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 67
#
# 0: 480x640 14 persons, 6 cars, 2 traffic lights, 1 stop sign, 1 backpack, 32.2ms
# Speed: 1.9ms preprocess, 32.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 177, yellow_pixels: 0, green_pixels: 2
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 68
#
# 0: 480x640 16 persons, 1 bicycle, 5 cars, 3 traffic lights, 1 stop sign, 32.0ms
# Speed: 1.2ms preprocess, 32.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 194, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 69
#
# 0: 480x640 15 persons, 6 cars, 3 traffic lights, 1 stop sign, 32.1ms
# Speed: 1.2ms preprocess, 32.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 188, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 70
#
# 0: 480x640 15 persons, 6 cars, 3 traffic lights, 1 stop sign, 32.8ms
# Speed: 1.2ms preprocess, 32.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 195, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 71
#
# 0: 480x640 15 persons, 6 cars, 3 traffic lights, 1 stop sign, 32.0ms
# Speed: 2.1ms preprocess, 32.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 196, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 72
#
# 0: 480x640 15 persons, 5 cars, 3 traffic lights, 1 stop sign, 32.3ms
# Speed: 1.3ms preprocess, 32.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 196, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 73
#
# 0: 480x640 15 persons, 5 cars, 2 traffic lights, 1 stop sign, 32.3ms
# Speed: 1.8ms preprocess, 32.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 191, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 74
#
# 0: 480x640 14 persons, 5 cars, 3 traffic lights, 1 stop sign, 32.2ms
# Speed: 1.2ms preprocess, 32.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 191, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 75
#
# 0: 480x640 14 persons, 5 cars, 3 traffic lights, 1 stop sign, 32.2ms
# Speed: 1.2ms preprocess, 32.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 178, yellow_pixels: 0, green_pixels: 8
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 76
#
# 0: 480x640 14 persons, 5 cars, 1 truck, 3 traffic lights, 1 stop sign, 32.0ms
# Speed: 1.2ms preprocess, 32.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 179, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 77
#
# 0: 480x640 14 persons, 5 cars, 3 traffic lights, 1 stop sign, 30.6ms
# Speed: 1.2ms preprocess, 30.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 181, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 78
#
# 0: 480x640 14 persons, 5 cars, 3 traffic lights, 1 stop sign, 30.6ms
# Speed: 1.5ms preprocess, 30.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 179, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 79
#
# 0: 480x640 14 persons, 6 cars, 3 traffic lights, 1 stop sign, 31.9ms
# Speed: 1.2ms preprocess, 31.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 4, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 172, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 80
#
# 0: 480x640 14 persons, 5 cars, 3 traffic lights, 1 stop sign, 31.8ms
# Speed: 1.3ms preprocess, 31.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 177, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# red_pixels: 4, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 81
#
# 0: 480x640 14 persons, 4 cars, 2 traffic lights, 1 stop sign, 31.9ms
# Speed: 1.2ms preprocess, 31.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 180, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 82
#
# 0: 480x640 14 persons, 4 cars, 2 traffic lights, 1 stop sign, 32.1ms
# Speed: 1.3ms preprocess, 32.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 180, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 83
#
# 0: 480x640 16 persons, 4 cars, 2 traffic lights, 1 stop sign, 31.8ms
# Speed: 1.2ms preprocess, 31.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 184, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 84
#
# 0: 480x640 16 persons, 4 cars, 2 traffic lights, 1 stop sign, 31.9ms
# Speed: 1.2ms preprocess, 31.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 186, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 85
#
# 0: 480x640 18 persons, 5 cars, 2 traffic lights, 1 stop sign, 31.2ms
# Speed: 1.3ms preprocess, 31.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 181, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 86
#
# 0: 480x640 16 persons, 5 cars, 2 traffic lights, 1 stop sign, 30.6ms
# Speed: 1.2ms preprocess, 30.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 181, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# vehicles crossed on red: 0
# people crossed: 0
# vehicles crossed: 0
# frame_nr: 87
#
# 0: 480x640 17 persons, 5 cars, 2 traffic lights, 1 stop sign, 31.8ms
# Speed: 1.2ms preprocess, 31.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 181, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 0
# vehicles crossed on green: 0
# people crossed on red: 0
# ...
# red_pixels: 16, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# Traffic light color after for: Red
# people crossed on green: 14
# vehicles crossed on green: 58
# people crossed on red: 1
# vehicles crossed on red: 1
# people crossed: 14
# vehicles crossed: 61
# frame_nr: 2532
#
# 0: 480x640 6 persons, 6 cars, 1 truck, 2 traffic lights, 1 stop sign, 1 potted plant, 32.3ms
# Speed: 1.5ms preprocess, 32.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 168, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# red_pixels: 16, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# Traffic light color after for: Red
# people crossed on green: 14
# vehicles crossed on green: 58
# people crossed on red: 1
# vehicles crossed on red: 1
# people crossed: 14
# vehicles crossed: 61
# frame_nr: 2533
#
# 0: 480x640 8 persons, 6 cars, 1 truck, 2 traffic lights, 1 fire hydrant, 1 stop sign, 1 potted plant, 32.7ms
# Speed: 1.1ms preprocess, 32.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 172, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# red_pixels: 16, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# Traffic light color after for: Red
# people crossed on green: 14
# vehicles crossed on green: 58
# people crossed on red: 1
# vehicles crossed on red: 1
# people crossed: 14
# vehicles crossed: 61
# frame_nr: 2534
#
# 0: 480x640 7 persons, 5 cars, 1 truck, 2 traffic lights, 1 stop sign, 1 parking meter, 1 potted plant, 31.5ms
# Speed: 1.4ms preprocess, 31.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 16, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 172, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 14
# vehicles crossed on green: 58
# people crossed on red: 1
# vehicles crossed on red: 1
# people crossed: 14
# vehicles crossed: 61
# frame_nr: 2535
#
# 0: 480x640 7 persons, 6 cars, 1 truck, 2 traffic lights, 1 stop sign, 1 potted plant, 32.5ms
# Speed: 1.2ms preprocess, 32.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 180, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# red_pixels: 12, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# Traffic light color after for: Red
# people crossed on green: 14
# vehicles crossed on green: 58
# people crossed on red: 1
# vehicles crossed on red: 1
# people crossed: 14
# vehicles crossed: 61
# frame_nr: 2536
#
# 0: 480x640 7 persons, 5 cars, 1 truck, 2 traffic lights, 1 stop sign, 1 potted plant, 32.8ms
# Speed: 1.1ms preprocess, 32.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 16, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 168, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 14
# vehicles crossed on green: 58
# people crossed on red: 1
# vehicles crossed on red: 1
# people crossed: 14
# vehicles crossed: 61
# frame_nr: 2537
#
# 0: 480x640 8 persons, 5 cars, 1 truck, 2 traffic lights, 1 stop sign, 1 parking meter, 1 potted plant, 32.5ms
# Speed: 1.2ms preprocess, 32.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 16, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 168, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 14
# vehicles crossed on green: 58
# people crossed on red: 1
# vehicles crossed on red: 1
# people crossed: 14
# vehicles crossed: 61
# frame_nr: 2538
#
# 0: 480x640 10 persons, 5 cars, 3 traffic lights, 1 stop sign, 1 parking meter, 1 potted plant, 33.0ms
# Speed: 1.2ms preprocess, 33.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 12, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 168, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# red_pixels: 168, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 14
# vehicles crossed on green: 58
# people crossed on red: 1
# vehicles crossed on red: 1
# people crossed: 14
# vehicles crossed: 61
# frame_nr: 2539
#
# 0: 480x640 8 persons, 5 cars, 1 truck, 2 traffic lights, 1 stop sign, 1 handbag, 1 potted plant, 32.3ms
# Speed: 1.2ms preprocess, 32.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 191, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# red_pixels: 8, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# Traffic light color after for: Red
# people crossed on green: 14
# vehicles crossed on green: 59
# people crossed on red: 1
# vehicles crossed on red: 1
# people crossed: 14
# vehicles crossed: 62
# frame_nr: 2540
#
# 0: 480x640 9 persons, 5 cars, 1 truck, 2 traffic lights, 1 stop sign, 1 potted plant, 32.6ms
# Speed: 1.2ms preprocess, 32.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 180, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# Traffic light color after for: Red
# people crossed on green: 14
# vehicles crossed on green: 59
# people crossed on red: 1
# vehicles crossed on red: 1
# people crossed: 14
# vehicles crossed: 62
# frame_nr: 2541
#
# 0: 480x640 8 persons, 5 cars, 1 truck, 2 traffic lights, 1 stop sign, 32.6ms
# Speed: 1.2ms preprocess, 32.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 194, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 14
# vehicles crossed on green: 59
# people crossed on red: 1
# vehicles crossed on red: 1
# people crossed: 14
# vehicles crossed: 62
# frame_nr: 2542
#
# 0: 480x640 9 persons, 5 cars, 2 traffic lights, 1 stop sign, 1 potted plant, 32.8ms
# Speed: 1.2ms preprocess, 32.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 200, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 14
# vehicles crossed on green: 59
# people crossed on red: 1
# vehicles crossed on red: 1
# people crossed: 14
# vehicles crossed: 62
# frame_nr: 2543
#
# 0: 480x640 8 persons, 6 cars, 1 traffic light, 1 stop sign, 32.4ms
# Speed: 1.1ms preprocess, 32.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 200, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 14
# vehicles crossed on green: 59
# people crossed on red: 1
# vehicles crossed on red: 1
# people crossed: 14
# vehicles crossed: 62
# frame_nr: 2544
#
# 0: 480x640 9 persons, 6 cars, 2 traffic lights, 1 stop sign, 32.8ms
# Speed: 1.2ms preprocess, 32.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 187, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 14
# vehicles crossed on green: 59
# people crossed on red: 1
# vehicles crossed on red: 1
# people crossed: 14
# vehicles crossed: 62
# frame_nr: 2545
#
# 0: 480x640 7 persons, 6 cars, 1 traffic light, 1 stop sign, 32.3ms
# Speed: 1.1ms preprocess, 32.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 200, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 14
# vehicles crossed on green: 59
# people crossed on red: 1
# vehicles crossed on red: 1
# people crossed: 14
# vehicles crossed: 62
# frame_nr: 2546
#
# 0: 480x640 7 persons, 5 cars, 2 traffic lights, 1 stop sign, 32.6ms
# Speed: 1.1ms preprocess, 32.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 208, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# red_pixels: 0, yellow_pixels: 0, green_pixels: 4
# Traffic light color: not visible
# Traffic light color after for: Red
# people crossed on green: 14
# vehicles crossed on green: 59
# people crossed on red: 1
# vehicles crossed on red: 1
# people crossed: 14
# vehicles crossed: 62
# frame_nr: 2547
#
# 0: 480x640 9 persons, 5 cars, 1 truck, 2 traffic lights, 1 stop sign, 32.8ms
# Speed: 1.2ms preprocess, 32.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 183, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# Traffic light color after for: Red
# people crossed on green: 14
# vehicles crossed on green: 59
# people crossed on red: 1
# vehicles crossed on red: 1
# people crossed: 14
# vehicles crossed: 62
# frame_nr: 2548
#
# 0: 480x640 6 persons, 5 cars, 2 traffic lights, 1 fire hydrant, 1 stop sign, 1 potted plant, 32.1ms
# Speed: 1.1ms preprocess, 32.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 179, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# red_pixels: 8, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# Traffic light color after for: Red
# people crossed on green: 14
# vehicles crossed on green: 59
# people crossed on red: 1
# vehicles crossed on red: 1
# people crossed: 14
# vehicles crossed: 62
# frame_nr: 2549
#
# 0: 480x640 10 persons, 4 cars, 1 truck, 1 traffic light, 1 stop sign, 1 potted plant, 31.8ms
# Speed: 1.1ms preprocess, 31.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 200, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 14
# vehicles crossed on green: 59
# people crossed on red: 1
# vehicles crossed on red: 1
# people crossed: 14
# vehicles crossed: 62
# frame_nr: 2550
#
# 0: 480x640 8 persons, 5 cars, 1 truck, 2 traffic lights, 1 stop sign, 1 potted plant, 31.4ms
# Speed: 1.1ms preprocess, 31.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 4, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 196, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 14
# vehicles crossed on green: 59
# people crossed on red: 1
# vehicles crossed on red: 1
# people crossed: 14
# vehicles crossed: 62
# frame_nr: 2551
#
# 0: 480x640 9 persons, 4 cars, 1 truck, 2 traffic lights, 1 stop sign, 1 potted plant, 32.5ms
# Speed: 1.6ms preprocess, 32.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 8, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 200, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 14
# vehicles crossed on green: 59
# people crossed on red: 1
# vehicles crossed on red: 1
# people crossed: 14
# vehicles crossed: 62
# frame_nr: 2552
#
# 0: 480x640 10 persons, 4 cars, 1 truck, 2 traffic lights, 1 stop sign, 31.3ms
# Speed: 1.8ms preprocess, 31.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 4, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 200, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 14
# vehicles crossed on green: 59
# people crossed on red: 1
# vehicles crossed on red: 1
# people crossed: 14
# vehicles crossed: 62
# frame_nr: 2553
#
# 0: 480x640 11 persons, 4 cars, 1 truck, 2 traffic lights, 1 stop sign, 32.5ms
# Speed: 1.0ms preprocess, 32.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 200, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# red_pixels: 8, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# Traffic light color after for: Red
# people crossed on green: 14
# vehicles crossed on green: 59
# people crossed on red: 1
# vehicles crossed on red: 1
# people crossed: 14
# vehicles crossed: 62
# frame_nr: 2554
#
# 0: 480x640 9 persons, 4 cars, 1 truck, 2 traffic lights, 1 stop sign, 1 potted plant, 32.7ms
# Speed: 1.1ms preprocess, 32.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 12, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 196, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 14
# vehicles crossed on green: 59
# people crossed on red: 1
# vehicles crossed on red: 1
# people crossed: 14
# vehicles crossed: 62
# frame_nr: 2555
#
# 0: 480x640 10 persons, 4 cars, 2 traffic lights, 1 stop sign, 1 potted plant, 32.8ms
# Speed: 1.1ms preprocess, 32.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 198, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# red_pixels: 12, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# Traffic light color after for: Red
# people crossed on green: 14
# vehicles crossed on green: 59
# people crossed on red: 1
# vehicles crossed on red: 1
# people crossed: 14
# vehicles crossed: 62
# frame_nr: 2556
#
# 0: 480x640 10 persons, 4 cars, 2 traffic lights, 1 stop sign, 1 potted plant, 32.7ms
# Speed: 1.1ms preprocess, 32.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 12, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 190, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 14
# vehicles crossed on green: 59
# people crossed on red: 1
# vehicles crossed on red: 1
# people crossed: 14
# vehicles crossed: 62
# frame_nr: 2557
#
# 0: 480x640 9 persons, 5 cars, 2 traffic lights, 1 stop sign, 1 potted plant, 32.9ms
# Speed: 1.6ms preprocess, 32.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 12, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 196, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 14
# vehicles crossed on green: 59
# people crossed on red: 1
# vehicles crossed on red: 1
# people crossed: 14
# vehicles crossed: 62
# frame_nr: 2558
#
# 0: 480x640 8 persons, 4 cars, 2 traffic lights, 1 stop sign, 1 potted plant, 32.1ms
# Speed: 1.8ms preprocess, 32.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 12, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 196, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# Traffic light color after for: Red
# people crossed on green: 14
# vehicles crossed on green: 59
# people crossed on red: 1
# vehicles crossed on red: 1
# people crossed: 14
# vehicles crossed: 62
# frame_nr: 2559
#
# 0: 480x640 10 persons, 4 cars, 1 truck, 3 traffic lights, 1 stop sign, 1 potted plant, 32.9ms
# Speed: 1.1ms preprocess, 32.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# red_pixels: 12, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# red_pixels: 196, yellow_pixels: 0, green_pixels: 0
# pred: [1, 0, 0]
# Traffic light color: Red
# red_pixels: 0, yellow_pixels: 0, green_pixels: 0
# Traffic light color: not visible
# Traffic light color after for: Red
# people crossed on green: 14
# vehicles crossed on green: 59
# people crossed on red: 1
# vehicles crossed on red: 1
# people crossed: 14
# vehicles crossed: 62
